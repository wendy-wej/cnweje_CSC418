# %% [markdown]
# ## Sharpening Images

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread("img/sst-foyer.jpg")
    
plt.subplot(1,2,1)
plt.title("Original")
plt.imshow(image)

#Sharpening kernel
kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

#Sharpen image
sharpened_image = cv2.filter2D(image, -1, kernel)

cv2.imwrite(f'img/sharpened_image.jpg', sharpened_image)

#sharpened image
plt.subplot(1, 2, 2)
plt.title("Sharpening")
plt.imshow(sharpened_image)
plt.show()
